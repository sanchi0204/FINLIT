# %%
import pandas as pd

# %%
df = pd.read_csv('Axis-bank.csv')

# %%
df.head(20)
# Out:
#    Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0   Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                    Axis Mutual Fund
# 2   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 3   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 4   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 5   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 6   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 7   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 8   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 9   120465;Axis Bluechip Fund - Direct Plan - Grow...
# 10  120465;Axis Bluechip Fund - Direct Plan - Grow...
# 11  120465;Axis Bluechip Fund - Direct Plan - Grow...
# 12  120465;Axis Bluechip Fund - Direct Plan - Grow...
# 13  120465;Axis Bluechip Fund - Direct Plan - Grow...
# 14  120465;Axis Bluechip Fund - Direct Plan - Grow...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33765 entries, 0 to 33764
# Data columns (total 1 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date  33765 non-null  object
# dtypes: object(1)
# memory usage: 263.9+ KB

# %%
cb = df['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']

# %%
cb
# Out:
# 0        Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                         Axis Mutual Fund
# 2        120465;Axis Bluechip Fund - Direct Plan - Grow...
# 3        120465;Axis Bluechip Fund - Direct Plan - Grow...
# 4        120465;Axis Bluechip Fund - Direct Plan - Grow...
#                                ...
# 33760    141928;Axis Flexi Cap Fund - Regular Plan - ID...
# 33761    141928;Axis Flexi Cap Fund - Regular Plan - ID...
# 33762    141928;Axis Flexi Cap Fund - Regular Plan - ID...
# 33763    141928;Axis Flexi Cap Fund - Regular Plan - ID...
# 33764    141928;Axis Flexi Cap Fund - Regular Plan - ID...
# Name: Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date, Length: 33765, dtype: object

# %%
def func(bc):
    l=list(map(str,bc.split(';')))
    return l

# %%
li = list(map(func,cb))

# %%
len(li)
# Out:
# 33765

# %%
pi=[[li[2][0],li[2][1]]]
pil = li[2][4]
print(pi,pil)
# Out:
# [['120465', 'Axis Bluechip Fund - Direct Plan - Growth']] 42.21

# %%
print(len(li))
print(len(li[123]))
# Out:
# 33765
# 8

# %%
def listreturn(l):
    i=0
    p=[[l[2][0],l[2][1]]]
    fl=0
    while i<len(l):
        if len(l[i])==8:
            if l[i][0]==p[fl][0]:
                p[fl].append(float(l[i][4]))
            else:
                k=[l[i][0],l[i][1],float(l[i][4])]
                p.append(k)
                fl+=1
        i+=1
    return p

# %%
dfl = listreturn(li)
print(dfl)
# Out:
# [['120465', 'Axis Bluechip Fund - Direct Plan - Growth', 42.21, 42.51, 42.73, 42.54, 42.37, 43.03, 43.41, 43.41, 43.1, 43.12, 42.6, 42.01, 42.73, 43.02, 42.91, 42.47, 42.11, 41.35, 40.81, 40.1, 41.84, 42.82, 43.15, 43.53, 43.64, 44.04, 43.96, 44.08, 44.23, 44.3, 44.9, 44.92, 44.55, 44.05, 43.67, 42.9, 42.93, 43.63, 43.6, 42.1, 42.63, 43.21, 44.15, 43.87, 43.59, 43.34, 43.79, 44.03, 43.68, 43.35, 43.35, 42.86, 42.35, 42.71, 42.64, 42.97, 42.32, 41.67, 42.19, 43.06, 42.65, 43.12, 42.48, 42.66, 43.11, 43.29, 43.18, 41.75, 42.13, 42.38, 42.48, 41.78, 41.6, 41.84, 41.62, 42.05, 42.5, 43.38, 43.48, 42.71, 42.84, 42.49, 42.8, 43.1, 43.28, 43.6, 43.25, 42.82, 42.66, 43.35, 44.04, 43.82, 43.52, 44.26, 44.25, 44.37, 44.68, 44.68, 44.73, 45.22, 45.18, 45.31, 45.68, 45.63, 45.63, 45.6, 45.35, 45.89, 46.03, 46.22, 46.42, 46.16, 46.07, 46.07, 46.2, 46.3, 46.02, 46.42, 46.56, 46.44, 46.29, 46.32, 46.19, 46.34, 46.68, 46.73, 46.89, 46.5, 46.43, 46.42, 46.69, 46.78, 46.88, 46.92, 46.47, 46.33, 46.88,
# ...

# %%
dfl1 = ['Scheme Id','Scheme Name']
i=2
s=li[2][0]
while i<len(li):
    if s!=li[i][0]:
        break
    dfl1.append(li[i][7])
    i+=1

# %%
dfl2 = ['Scheme Id','Scheme Name']
i=2
s=li[16000][0]
while i<len(li):
    if s==li[i][0]:
        dfl2.append(li[i][7])
    i+=1

# %%
len(dfl2)
# Out:
# 141

# %%
print(dfl1)
# Out:
# ['Scheme Id', 'Scheme Name', '01-Jan-2021', '04-Jan-2021', '05-Jan-2021', '06-Jan-2021', '07-Jan-2021', '08-Jan-2021', '11-Jan-2021', '12-Jan-2021', '13-Jan-2021', '14-Jan-2021', '15-Jan-2021', '18-Jan-2021', '19-Jan-2021', '20-Jan-2021', '21-Jan-2021', '22-Jan-2021', '25-Jan-2021', '27-Jan-2021', '28-Jan-2021', '29-Jan-2021', '01-Feb-2021', '02-Feb-2021', '03-Feb-2021', '04-Feb-2021', '05-Feb-2021', '08-Feb-2021', '09-Feb-2021', '10-Feb-2021', '11-Feb-2021', '12-Feb-2021', '15-Feb-2021', '16-Feb-2021', '17-Feb-2021', '18-Feb-2021', '19-Feb-2021', '22-Feb-2021', '23-Feb-2021', '24-Feb-2021', '25-Feb-2021', '26-Feb-2021', '01-Mar-2021', '02-Mar-2021', '03-Mar-2021', '04-Mar-2021', '05-Mar-2021', '08-Mar-2021', '09-Mar-2021', '10-Mar-2021', '12-Mar-2021', '15-Mar-2021', '16-Mar-2021', '17-Mar-2021', '18-Mar-2021', '19-Mar-2021', '22-Mar-2021', '23-Mar-2021', '24-Mar-2021', '25-Mar-2021', '26-Mar-2021', '30-Mar-2021', '31-Mar-2021', '01-Apr-2021', '05-Apr-2021', '06-Apr-2021', '07-Apr-2
# ...

# %%
gb = pd.read_csv('ICICI.txt')
gb.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Multi Cap...
# 1                       ICICI Prudential Mutual Fund
# 2  120381;ICICI Prudential MidCap Fund - Direct P...
# 3  120381;ICICI Prudential MidCap Fund - Direct P...
# 4  120381;ICICI Prudential MidCap Fund - Direct P...

# %%
lp = gb['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']

# %%
lp
# Out:
# 0        Open Ended Schemes ( Equity Scheme - Multi Cap...
# 1                             ICICI Prudential Mutual Fund
# 2        120381;ICICI Prudential MidCap Fund - Direct P...
# 3        120381;ICICI Prudential MidCap Fund - Direct P...
# 4        120381;ICICI Prudential MidCap Fund - Direct P...
#                                ...
# 57668    148988;ICICI Prudential Flexicap Fund - IDCW;I...
# 57669    148988;ICICI Prudential Flexicap Fund - IDCW;I...
# 57670    148988;ICICI Prudential Flexicap Fund - IDCW;I...
# 57671    148988;ICICI Prudential Flexicap Fund - IDCW;I...
# 57672    148988;ICICI Prudential Flexicap Fund - IDCW;I...
# Name: Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date, Length: 57673, dtype: object

# %%
lp = list(map(func,lp))

# %%
lp[4][4]
# Out:
# '125.90'

# %%
dflp = listreturn(lp)
print(dflp)
# Out:
# [['120381', 'ICICI Prudential MidCap Fund - Direct Plan -  Growth', 123.21, 125.25, 125.9, 126.27, 127.49, 128.67, 128.28, 129.13, 128.73, 129.0, 127.66, 124.99, 127.37, 128.29, 127.0, 125.47, 124.16, 122.58, 121.94, 121.59, 125.14, 128.51, 130.4, 131.8, 130.62, 132.4, 132.78, 133.89, 134.79, 134.67, 135.87, 135.85, 135.89, 135.43, 133.68, 131.9, 133.22, 134.49, 136.56, 135.19, 136.69, 138.59, 140.97, 141.81, 139.43, 139.98, 139.65, 140.61, 139.7, 139.28, 139.66, 136.83, 135.41, 136.51, 137.27, 137.64, 135.01, 133.31, 135.32, 136.74, 137.02, 138.34, 136.1, 136.5, 138.64, 139.93, 140.17, 133.68, 134.9, 134.58, 135.79, 133.47, 133.68, 134.01, 134.78, 136.51, 138.58, 140.16, 139.38, 138.53, 139.55, 138.81, 139.71, 141.06, 141.23, 142.06, 143.05, 141.75, 140.5, 142.19, 144.48, 144.64, 144.72, 146.57, 147.73, 148.41, 149.12, 149.35, 149.48, 150.29, 149.67, 150.66, 152.3, 153.45, 155.66, 156.16, 154.92, 157.58, 157.62, 157.13, 157.97, 156.86, 155.3, 154.03, 155.04, 155.37, 155.09, 155.54, 
# ...

# %%
len(dflp[7])
# Out:
# 145

# %%
len(dflp[7])
# Out:
# 145

# %%
gbe = pd.read_csv('SBI.txt')
gbe.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                    SBI Mutual Fund
# 2  119585;SBI Blue Chip Fund - Direct Plan - Inco...
# 3  119585;SBI Blue Chip Fund - Direct Plan - Inco...
# 4  119585;SBI Blue Chip Fund - Direct Plan - Inco...

# %%
lpp = gbe['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']

# %%
lpp = list(map(func,lpp))
dflpp = listreturn(lpp)
print(dflpp)
# Out:
# [['119585', 'SBI Blue Chip Fund - Direct Plan - Income Distribution cum Capital Withdrawal Option (IDCW)', 33.7984, 34.1958, 34.3432, 34.3456, 34.3611, 34.8637, 35.1498, 35.372, 35.3401, 35.3589, 34.8677, 34.439, 35.0274, 35.2338, 34.9455, 34.4557, 34.1966, 33.6133, 33.3467, 32.9833, 34.6599, 35.6404, 36.0655, 36.4558, 36.495, 37.0748, 37.0345, 37.1029, 37.1987, 37.2018, 37.7841, 37.7635, 37.6831, 37.4301, 36.9517, 36.2551, 36.4349, 37.0261, 37.2928, 36.0427, 36.6636, 37.1279, 37.7246, 37.4274, 36.9655, 37.0432, 37.2264, 37.4348, 37.0326, 36.7814, 36.6855, 36.1505, 35.7451, 36.1025, 36.1512, 36.4212, 35.6861, 35.1366, 35.599, 36.3113, 36.108, 36.5085, 35.8931, 35.9238, 36.3924, 36.4827, 36.347, 34.9181, 35.5378, 35.6795, 35.8879, 35.1966, 35.0881, 35.3948, 35.258, 35.563, 35.9538, 36.3317, 36.2367, 35.7108, 35.715, 35.3748, 35.726, 36.0063, 36.1193, 36.4642, 36.3275, 35.99, 35.8057, 36.3894, 36.8563, 36.7858, 36.6204, 37.2347, 37.4136, 37.3165, 37.4276, 37.4684, 37.645, 37.9295, 37.8
# ...

# %%
len(dflpp[4])
# Out:
# 145

# %%
hdfc = pd.read_csv('HDFC.txt')
hdfc.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                   HDFC Mutual Fund
# 2  119018;HDFC Top 100 Fund - Growth Option - Dir...
# 3  119018;HDFC Top 100 Fund - Growth Option - Dir...
# 4  119018;HDFC Top 100 Fund - Growth Option - Dir...

# %%
hf = hdfc['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']
hf = list(map(func,hf))
hfp = listreturn(hf)
print(hfp)
# Out:
# [['119018', 'HDFC Top 100 Fund - Growth Option - Direct Plan', 560.572, 567.097, 569.689, 569.845, 571.642, 579.239, 583.945, 590.429, 594.69, 596.806, 591.127, 581.929, 591.912, 595.83, 589.852, 580.704, 577.203, 566.483, 564.244, 557.536, 585.417, 603.697, 611.968, 619.45, 620.496, 629.69, 628.115, 627.0, 627.744, 626.591, 635.321, 636.144, 636.359, 637.934, 627.035, 613.67, 618.111, 629.529, 638.436, 615.772, 624.523, 631.735, 642.33, 634.056, 625.443, 630.18, 631.005, 633.922, 629.5, 626.802, 624.924, 613.871, 607.348, 613.714, 612.024, 614.685, 602.218, 592.348, 598.77, 609.444, 605.485, 613.236, 602.584, 602.871, 608.876, 609.58, 607.512, 582.053, 593.131, 597.327, 599.092, 588.152, 586.92, 591.411, 591.196, 596.243, 602.781, 609.639, 608.519, 602.18, 601.827, 598.02, 606.17, 609.626, 613.973, 622.362, 624.921, 621.271, 616.55, 625.943, 631.888, 631.094, 626.251, 637.85, 642.134, 641.509, 642.693, 644.539, 646.901, 653.143, 652.785, 655.004, 658.78, 659.574, 666.137, 666.179, 6
# ...

# %%
len(hfp[7])
# Out:
# 145

# %%
kt = pd.read_csv('kotak.txt')
kt.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                         Kotak Mahindra Mutual Fund
# 2  114458;Kotak Bluechip Fund - Growth;INF174K011...
# 3  114458;Kotak Bluechip Fund - Growth;INF174K011...
# 4  114458;Kotak Bluechip Fund - Growth;INF174K011...

# %%
kk = kt['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']
kk = list(map(func,kk))
kfp = listreturn(kk)
print(kfp)
# Out:
# [['114458', 'Kotak Bluechip Fund - Growth', 294.733, 297.818, 300.004, 299.493, 299.103, 303.523, 305.989, 307.268, 306.917, 307.723, 304.357, 301.148, 305.448, 307.79, 306.224, 303.327, 300.592, 295.391, 292.753, 289.534, 301.392, 307.762, 309.98, 312.436, 311.726, 316.799, 317.572, 318.399, 319.561, 320.482, 323.216, 322.369, 321.519, 320.041, 316.773, 310.517, 311.6, 316.63, 318.762, 309.086, 313.528, 317.121, 322.857, 321.923, 318.89, 319.009, 320.984, 322.486, 319.768, 317.522, 318.259, 313.25, 309.623, 313.717, 313.792, 316.178, 310.712, 305.738, 309.635, 316.255, 314.176, 317.27, 312.379, 312.715, 315.646, 317.242, 316.949, 306.092, 308.811, 309.798, 310.8, 305.889, 305.484, 306.763, 305.527, 308.919, 311.993, 316.356, 316.576, 312.349, 312.127, 309.314, 312.019, 313.559, 314.137, 316.328, 315.448, 313.356, 312.109, 316.701, 320.878, 320.969, 318.911, 323.721, 324.458, 325.051, 326.814, 327.812, 328.997, 332.527, 331.416, 332.574, 335.21, 335.074, 337.187, 337.787, 335.374, 33
# ...

# %%
len(kfp[7])
# Out:
# 145

# %%
ut = pd.read_csv('UTI.txt')
ut.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Large Cap...
# 1                                    UTI Mutual Fund
# 2  100651;UTI - Master Share-Growth Option;INF789...
# 3  100651;UTI - Master Share-Growth Option;INF789...
# 4  100651;UTI - Master Share-Growth Option;INF789...

# %%
ui = ut['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']
ui = list(map(func,ui))
ufp = listreturn(ui)
print(ufp)
# Out:
# [['100651', 'UTI - Master Share-Growth Option', 153.2348, 154.7373, 155.5451, 155.4059, 155.6027, 157.8412, 159.5473, 159.9925, 159.799, 160.0068, 158.2561, 156.1192, 158.6613, 159.9688, 159.0497, 156.9743, 155.9956, 152.8864, 151.6048, 149.1915, 155.6545, 159.6377, 161.291, 162.7854, 162.6945, 165.3798, 165.1452, 164.9229, 165.3751, 165.1277, 167.0467, 166.3836, 165.3231, 164.4542, 162.7732, 159.8024, 160.4368, 162.904, 163.4267, 158.2007, 160.3151, 162.4558, 165.755, 164.5703, 162.7392, 162.7862, 163.7378, 164.7826, 163.7324, 162.7584, 162.6055, 160.7339, 158.743, 160.4526, 160.6075, 161.975, 159.3273, 157.0139, 159.3684, 162.9466, 161.7615, 163.2094, 160.7082, 161.0552, 162.7654, 163.5601, 163.5364, 157.9775, 159.5812, 160.4131, 160.8265, 158.4686, 158.0571, 158.9382, 157.9644, 159.5555, 161.5109, 163.7454, 163.7833, 161.2907, 161.6419, 160.0159, 161.4449, 162.615, 163.2953, 164.4884, 163.9669, 162.7606, 161.9826, 164.3718, 166.1563, 165.48, 164.2917, 166.9545, 167.3395, 167.7259,
# ...

# %%
len(ufp[8])
# Out:
# 145

# %%
sun = pd.read_csv('Sundaram.txt')
sun.head()
# Out:
#   Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date
# 0  Open Ended Schemes ( Equity Scheme - Multi Cap...
# 1                               Sundaram Mutual Fund
# 2  147587;Sundaram Equity Fund Direct Plan - Grow...
# 3  147587;Sundaram Equity Fund Direct Plan - Grow...
# 4  147587;Sundaram Equity Fund Direct Plan - Grow...

# %%
su = sun['Scheme Code;Scheme Name;ISIN Div Payout/ISIN Growth;ISIN Div Reinvestment;Net Asset Value;Repurchase Price;Sale Price;Date']
su = list(map(func,su))
sfp = listreturn(su)
print(sfp)
# Out:
# [['147587', 'Sundaram Equity Fund Direct Plan - Growth', 12.4817, 12.6314, 12.6998, 12.7201, 12.7714, 12.8724, 12.9416, 13.0236, 13.0094, 13.0371, 12.8582, 12.6587, 12.8607, 12.9675, 12.882, 12.6927, 12.6142, 12.4306, 12.3014, 12.2039, 12.7224, 13.0342, 13.2184, 13.3249, 13.376, 13.6356, 13.5686, 13.6126, 13.7227, 13.7109, 13.8293, 13.8013, 13.8134, 13.7997, 13.6321, 13.4182, 13.5028, 13.7201, 13.8575, 13.5179, 13.6973, 13.8498, 14.1098, 14.0937, 13.8767, 13.947, 13.8853, 13.9861, 13.9513, 13.8505, 13.8805, 13.6001, 13.4215, 13.561, 13.5706, 13.6451, 13.3947, 13.1523, 13.3439, 13.6373, 13.617, 13.7802, 13.5206, 13.5833, 13.7429, 13.8624, 13.8745, 13.2538, 13.4375, 13.4242, 13.5509, 13.3062, 13.2599, 13.3366, 13.3061, 13.4246, 13.6127, 13.738, 13.7692, 13.7066, 13.7795, 13.6685, 13.7998, 13.8926, 13.8834, 13.9788, 13.9837, 13.8745, 13.7617, 14.0023, 14.1867, 14.2476, 14.2106, 14.4193, 14.4462, 14.5029, 14.5445, 14.6196, 14.6132, 14.7031, 14.6363, 14.7239, 14.8521, 14.8747, 14.9804, 15
# ...

# %%
len(sfp[72])
# Out:
# 214

# %%
very_high_risk=[]
high_risk=[]
moderate_low_risk=[]

# %%
def funcf(df):
    list1=['120505','120504','125354','125351','120381','120380','120599','120598','125497','125496','119716','119715','130503','130504','118989','118988','120164','120163','119775','119774','120727','120726','120665','120664','119589','119588','129212','129211']
    list2=['120465','120466','120503','120502','120586','120585','120592','120593','119585','119598','119718','119717','118955','118954','118929','118928','120152','120153','120166','120165','120662','120663','120715','120714','119578','119577','119542','119545']
    list3=['120437','120438','120439','120436','120510','120511','120512','120754','131478','120755','120616','120613','120615','120614','119816','119813','119815','119817','119828','119784','119829','119015','119016','133367','145039','145034','145036','145035','133812','133810','133811','119739','125254','119738']
    i=0
    while i<len(df):
        if df[i][0] in list1:
            very_high_risk.append(df[i])
        elif df[i][0] in list2:
            high_risk.append(df[i])
        elif df[i][0] in list3:
            moderate_low_risk.append(df[i])
        i+=1

# %%
funcf(dfl)
funcf(dflp)
funcf(dflpp)
funcf(hfp)
funcf(kfp)
funcf(ufp)
funcf(sfp)

# %%
dataf = pd.DataFrame(very_high_risk,columns=dfl1)

# %%
dataf
# Out:
#    Scheme Id                                        Scheme Name  01-Jan-2021  \
# 0     120505            Axis Midcap Fund - Direct Plan - Growth      55.5000
# 1     120504              Axis Midcap Fund - Direct Plan - IDCW      37.1300
# 2     125354         Axis Small Cap Fund - Direct Plan - Growth      43.1100
# 3     125351           Axis Small Cap Fund - Direct Plan - IDCW      29.5600
# 4     120381  ICICI Prudential MidCap Fund - Direct Plan -  ...     123.2100
# 5     120380  ICICI Prudential MidCap Fund - Direct Plan -  ...      30.5500
# 6     120599  ICICI Prudential Multicap Fund - Direct Plan -...     352.6600
# 7     120598  ICICI Prudential Multicap Fund - Direct Plan -...      30.9000
# 8     119716      SBI Magnum MIDCAP FUND - DIRECT PLAN - GROWTH     100.8869
# 9     119715  SBI Magnum MidCap Fund - Direct Plan - Income ...      57.1972
# 10    125497          SBI Small Cap Fund - Direct Plan - Growth      78.9610
# ...

# %%
dataf.to_csv('Very_High_Risk.csv')

# %%
datafe = pd.DataFrame(high_risk,columns=dfl1)

# %%
datafe
# Out:
#    Scheme Id                                        Scheme Name  01-Jan-2021  \
# 0     120465          Axis Bluechip Fund - Direct Plan - Growth      42.2100
# 1     120466            Axis Bluechip Fund - Direct Plan - IDCW      20.6900
# 2     120503  Axis Long Term Equity Fund - Direct Plan - Gro...      64.9820
# 3     120502    Axis Long Term Equity Fund - Direct Plan - IDCW      46.7198
# 4     120586  ICICI Prudential Bluechip Fund - Direct Plan -...      54.0800
# 5     120585  ICICI Prudential Bluechip Fund - Direct Plan -...      36.9600
# 6     120592  ICICI Prudential Long Term Equity Fund (Tax Sa...     481.6500
# 7     120593  ICICI Prudential Long Term Equity Fund (Tax Sa...      30.2800
# 8     119585  SBI Blue Chip Fund - Direct Plan - Income Dist...      33.7984
# 9     119598             SBI BLUE CHIP FUND-DIRECT PLAN -GROWTH      52.0788
# 10    119718    SBI Flexicap Fund - DIRECT PLAN - Growth Option      62.5565
# ...

# %%
datafe.to_csv('High_Risk.csv')

# %%
dataff = pd.DataFrame(moderate_low_risk,columns=dfl2)
dataff
# Out:
#    Scheme Id                                        Scheme Name  01-Jan-2021  \
# 0     120510  Axis Short Term Fund - Direct Plan - Growth Op...      25.3243
# 1     120511  Axis Short Term Fund - Direct Plan - Monthly IDCW      10.1103
# 2     120512   Axis Short Term Fund - Direct Plan - Weekly IDCW      10.2597
# 3     120437  Axis Banking & PSU Debt Fund - Direct Plan - D...    1039.1310
# 4     120438  Axis Banking & PSU Debt Fund - Direct Plan - G...    2088.9476
# 5     120439  Axis Banking & PSU Debt Fund - Direct Plan - M...    1034.2525
# 6     120436  Axis Banking & PSU Debt Fund - Direct Plan - W...    1039.6444
# 7     120754  ICICI Prudential Short Term Fund - Direct Plan...      48.3760
# 8     131478  ICICI Prudential Short Term Fund - Direct Plan...      13.7075
# 9     120755  ICICI Prudential Short Term Fund - Direct Plan...      12.6784
# 10    120616  ICICI Prudential Regular Savings Fund - Direct...      53.4898
# ...

# %%
dataff.to_csv('moderate_low_risk.csv')
